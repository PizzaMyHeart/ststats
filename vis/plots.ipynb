# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../data/data.csv').drop('Unnamed: 0', axis=1)

# %%
sns.relplot(x='year', y='ratio', hue='specialty', kind='line', data=df[df['level']==1])
