# %% [markdown]
# This should probably be a .py script.

# %%
import pandas as pd

# %% [markdown]
# Change these variables accordingly.

# %%
year = '2013'
filename = '2013.txt'

# %%
def read_txt(filename):
    with open(filename, 'r') as src:
        values = [line for line in src]
        return values
    
def build_dict(values):
    data = {'specialty': [],
            'level': [],
            'applications': [],
            'posts': [],
            'ratio': []}

    data['specialty'] = values[0::5]
    data['level'] = values[1::5]
    data['applications'] = values[2::5]
    data['posts'] = values[3::5]
    data['ratio'] = values[4::5]
    
    return data

# %%
data = build_dict(read_txt(filename))
df = pd.DataFrame.from_dict(data)
df['year'] = year

# %%
df
# Out:
#                             specialty  level applications    posts    ratio  \
# 0        ﻿ACCS - Emergency Medicine\n  ST1\n        534\n    203\n    2.6\n
# 1                      Anaesthetics\n  CT1\n       1189\n    478\n    2.5\n
# 2             Broad Based Training \n  CT1\n        429\n     52\n    8.3\n
# 3           Cardiothoracic Surgery \n  CT1\n         68\n      6\n   11.3\n
# 4                Clinical Radiology\n  ST1\n        751\n    185\n    4.1\n
# 5             Core Medical Training\n  CT1\n       3088\n   1209\n    2.6\n
# 6         Core Psychiatric Training\n  CT1\n        650\n    437\n    1.5\n
# 7            Core Surgical Training\n  CT1\n       1296\n    676\n    1.9\n
# 8                  General Practice\n  ST1\n       6447\n   2787\n    2.3\n
# 9                    Histopathology\n  ST1\n        154\n    120\n    1.3\n
# 10  Medical Microbiology & Virology\n  ST1\n        108\n     21\n    5.1\n
# 11                     Neurosurgery\n  ST1\n        183\n     37\n    4.9\n
# 12       Obstetrics and Gynaecology\n  ST1\n        591\n    204\n    2.9\n
# 13                    Ophthalmology\n  ST1\n        323\n     71\n    4.5\n
# 14     Paediatrics and Child Health\n  ST1\n        793\n    360\n    2.2\n
# 15                    Public Health\n  ST1\n        602\n     70\n      8.6
#
#     year
# 0   2013
# 1   2013
# 2   2013
# 3   2013
# 4   2013
# 5   2013
# 6   2013
# 7   2013
# 8   2013
# 9   2013
# 10  2013
# 11  2013
# 12  2013
# 13  2013
# 14  2013
# 15  2013

# %%
pd.DataFrame.to_csv(df, f'{year}.csv')
